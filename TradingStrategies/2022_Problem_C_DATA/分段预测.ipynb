# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("gold-pre.csv")
a = df.iloc[3:6]
a
# ls =[]
# ls.append(b['yhat'][0])
# ls.append(b['yhat'][1])
# ls.append(b['yhat'][2])
# ls.index(min(ls))
# Out:
#           ds         yhat
# 3  2016.9.15  1320.588886
# 4  2016.9.16  1318.432368
# 5  2016.9.17  1318.432368

# %%
for i in range(0,len(df),3):
    ls = []
    df = pd.read_csv("gold-pre.csv")
    b = df.iloc[i:i+3]
    ls.append(b['yhat'][i])
    ls.append(b['yhat'][i+1])
    ls.append(b['yhat'][i+2])
    # print(ls)
    if ls.index(min(ls)) > ls.index(max(ls)):
        print(0-(max(ls)-min(ls))/min(ls))
    else:
        print((max(ls)-min(ls))/min(ls))
    ls.clear()
# Out:
# -0.0026743231288246998
# -0.0016356682772217903
# -0.007758110714013684
# -0.004297364615121613
# -0.00632036811144997
# -0.0037506536664978084
# 0.0
# -0.0018845116593719006
# -0.0006010968123002015
# -0.0015501735247613942
# -0.0002562474145922468
# -0.00015174544722418212
# -0.00029644047317993125
# 0.0
# -0.0009649184391909513
# -0.0007656917656029399
# -0.00452136113592561
# -0.0031672427963221417
# -0.005395425719218974
# -0.004063250896137937
# 0.0
# -0.004022090537379479
# -0.0020067507640099324
# -0.008194192097527624
# -0.003881517892112913
# -0.005398047641254449
# -0.0030648566878384957
# 0.0
# -0.0012616800181798823
# -0.0002651489994748795
# 0.00044025790690346194
# 0.0011988633209183517
# 0.002753233378603759
# 0.0024678197852634936
# 0.0
# 0.0
# 0.0026158870116149992
# 0.0
# 0.0052515488567438755
# 0.0006443064355078498
# 0.0016208243454709206
# 0.0008166140975488457
# 0.00042083210751993273
# -0.0002551821048608741
# 0.0
# 6.664032147870258e-05
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_excel("LBMA-GOLD_re.xlsx")
df
# Out:
#            Date  USD (PM)
# 0    2016-09-11   1324.60
# 1    2016-09-12   1324.60
# 2    2016-09-13   1323.65
# 3    2016-09-14   1321.75
# 4    2016-09-15   1310.80
# ...         ...       ...
# 1821 2021-09-06   1821.60
# 1822 2021-09-07   1802.15
# 1823 2021-09-08   1786.00
# 1824 2021-09-09   1788.25
# 1825 2021-09-10   1794.60
#
# [1826 rows x 2 columns]

# %%
for i in df['USD (PM)']:
    if str(i) == "nan":
        print(1000)
    else:
        print(0.01)
# Out:
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 1000
# 1000
# 1000
# 0.01
# 0.01
# 1000
# 1000
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# 0.01
# 0.01
# 0.01
# 0.01
# 1000
# 1000
# 0.01
# ...
